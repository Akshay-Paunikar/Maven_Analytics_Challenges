# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# show full output
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

# %%
# dataset
data = pd.read_csv("E:\Maven_Analytics_Challenges\Everest_Challenge\HimalayanExpeditions\members_expedition.csv")

data.shape
# Out:
# (89089, 107)

# %%
data.head()
# Out:
#        expid  membid peakid_x  myear mseason         fname      lname sex  \
# 0  AMAD01101       2     AMAD   2001  Spring         Rohan    Buckley   M
# 1  AMAD01101       1     AMAD   2001  Spring  Marc Cameron   Fairhead   M
# 2  AMAD01101       3     AMAD   2001  Spring          Mark  Schroeder   M
# 3  AMAD01101       4     AMAD   2001  Spring         Colin      Smith   M
# 4  AMAD01101       5     AMAD   2001  Spring         Naomi      Smith   F
#
#      citizen   status  leader  deputy  bconly  nottobc  support  disabled  \
# 0  Australia  Climber   False   False   False    False    False     False
# 1  Australia   Leader    True   False   False    False    False     False
# 2  Australia  Climber   False   False   False    False    False     False
# 3  Australia  Climber   False   False   False    False    False     False
# 4  Australia  Climber   False   False   False    False    False     False
#
#    hired  sherpa  tibetan  msuccess  mclaimed  mdisputed  msolo  mtraverse  \
# 0  False   False    False     False     False      False  False      False
# 1  False   False    False     False     False      False  False      False
# 2  False   False    False     False     False      False  False      False
# 3  False   False    False     False     False      False  False      False
# 4  False   False    False     False     False      False  False      False
#
#     mski  mparapente  mspeed  mhighpt  mroute1  mroute2  mroute3  mascent1  \
# 0  False       False   False    False        0        0        0         0
# 1  False       False   False     True        1        0        0         0
# 2  False       False   False     True        1        0        0         0
# 3  False       False   False    False        0        0        0         0
# 4  False       False   False    False        0        0        0         0
#
#    mascent2  mascent3  mo2used  mo2none  mo2climb  mo2descent  mo2sleep  \
# 0         0         0    False     True     False       False     False
# 1         0         0    False     True     False       False     False
# 2         0         0    False     True     False       False     False
# 3         0         0    False     True     False       False     False
# 4         0         0    False     True     False       False     False
#
#    mo2medical  death  deathhgtm               msmtbid  \
# 0       False  False          0         No summit bid
# 1       False  False          0  Aborted at high camp
# 2       False  False          0  Aborted at high camp
# 3       False  False          0         No summit bid
# 4       False  False          0         No summit bid
#
#                                             msmtterm  mchksum  year  season  \
# 0                  Did not climb or intent to summit  2439554  2001  Spring
# 1  Bad conditions (deep snow, avalanches, falling...  2438062  2001  Spring
# 2  Bad conditions (deep snow, avalanches, falling...  2435183  2001  Spring
# 3                  Did not climb or intent to summit  2437475  2001  Spring
# 4                  Did not climb or intent to summit  2438996  2001  Spring
#
#     host    route1     nation        leaders  \
# 0  Nepal  SW Ridge  Australia  Marc Fairhead
# 1  Nepal  SW Ridge  Australia  Marc Fairhead
# 2  Nepal  SW Ridge  Australia  Marc Fairhead
# 3  Nepal  SW Ridge  Australia  Marc Fairhead
# 4  Nepal  SW Ridge  Australia  Marc Fairhead
#
#                                  sponsor  success1  success2  success3  \
# 0  Australian Ama Dablam Expedition 2001     False     False     False
# 1  Australian Ama Dablam Expedition 2001     False     False     False
# 2  Australian Ama Dablam Expedition 2001     False     False     False
# 3  Australian Ama Dablam Expedition 2001     False     False     False
# 4  Australian Ama Dablam Expedition 2001     False     False     False
#
#    success4  claimed  disputed   smtdate  \
# 0     False    False     False  4/1/2001
# 1     False    False     False  4/1/2001
# 2     False    False     False  4/1/2001
# 3     False    False     False  4/1/2001
# 4     False    False     False  4/1/2001
#
#                                           termreason  highpoint  traverse  \
# 0  Bad conditions (deep snow, avalanching, fallin...       6200     False
# 1  Bad conditions (deep snow, avalanching, fallin...       6200     False
# 2  Bad conditions (deep snow, avalanching, fallin...       6200     False
# 3  Bad conditions (deep snow, avalanching, fallin...       6200     False
# 4  Bad conditions (deep snow, avalanching, fallin...       6200     False
#
#      ski  parapente  camps  rope  totmembers  smtmembers  mdeaths  tothired  \
# 0  False      False      2     0           5           0        0         0
# 1  False      False      2     0           5           0        0         0
# 2  False      False      2     0           5           0        0         0
# 3  False      False      2     0           5           0        0         0
# 4  False      False      2     0           5           0        0         0
#
#    smthired  hdeaths  nohired  o2used  o2none  o2climb  o2descent  o2sleep  \
# 0         0        0     True   False    True    False      False    False
# 1         0        0     True   False    True    False      False    False
# 2         0        0     True   False    True    False      False    False
# 3         0        0     True   False    True    False      False    False
# 4         0        0     True   False    True    False      False    False
#
#    o2medical  o2taken  o2unkwn  \
# 0      False    False    False
# 1      False    False    False
# 2      False    False    False
# 3      False    False    False
# 4      False    False    False
#
#                                            campsites  comrte  stdrte  primrte  \
# 0  BC(25/03,4600m),ABC(01/04,5300m),C1(04/04,5850...    True   False    False
# 1  BC(25/03,4600m),ABC(01/04,5300m),C1(04/04,5850...    True   False    False
# 2  BC(25/03,4600m),ABC(01/04,5300m),C1(04/04,5850...    True   False    False
# 3  BC(25/03,4600m),ABC(01/04,5300m),C1(04/04,5850...    True   False    False
# 4  BC(25/03,4600m),ABC(01/04,5300m),C1(04/04,5850...    True   False    False
#
#    primmem  primref   chksum peakid      pkname      location  heightm  \
# 0    False    False  2456477   AMAD  Ama Dablam  Khumbu Himal     6814
# 1    False    False  2456477   AMAD  Ama Dablam  Khumbu Himal     6814
# 2    False    False  2456477   AMAD  Ama Dablam  Khumbu Himal     6814
# 3    False    False  2456477   AMAD  Ama Dablam  Khumbu Himal     6814
# 4    False    False  2456477   AMAD  Ama Dablam  Khumbu Himal     6814
#
#    heightf   himal                   region  open  unlisted  trekking  \
# 0    22356  Khumbu  Khumbu-Rolwaling-Makalu  True     False     False
# 1    22356  Khumbu  Khumbu-Rolwaling-Makalu  True     False     False
# 2    22356  Khumbu  Khumbu-Rolwaling-Makalu  True     False     False
# 3    22356  Khumbu  Khumbu-Rolwaling-Makalu  True     False     False
# 4    22356  Khumbu  Khumbu-Rolwaling-Makalu  True     False     False
#
#         phost  pstatus   pyear pseason pmonth  pday     pexpid  \
# 0  Nepal only  Climbed  1961.0  Spring    Mar  13.0  AMAD61101
# 1  Nepal only  Climbed  1961.0  Spring    Mar  13.0  AMAD61101
# 2  Nepal only  Climbed  1961.0  Spring    Mar  13.0  AMAD61101
# 3  Nepal only  Climbed  1961.0  Spring    Mar  13.0  AMAD61101
# 4  Nepal only  Climbed  1961.0  Spring    Mar  13.0  AMAD61101
#
#                pcountry                                         psummiters
# 0  New Zealand, USA, UK  Mike Gill, Wally Romanes, Barry Bishop, Michae...
# 1  New Zealand, USA, UK  Mike Gill, Wally Romanes, Barry Bishop, Michae...
# 2  New Zealand, USA, UK  Mike Gill, Wally Romanes, Barry Bishop, Michae...
# 3  New Zealand, USA, UK  Mike Gill, Wally Romanes, Barry Bishop, Michae...
# 4  New Zealand, USA, UK  Mike Gill, Wally Romanes, Barry Bishop, Michae...

# %%
data['termreason'].value_counts()
# Out:
# Success (main peak)                                                             58689
# Bad weather (storms, high winds)                                                 9104
# Bad conditions (deep snow, avalanching, falling ice, or rock)                    7510
# Route technically too difficult, lack of experience, strength, or motivation     2633
# Other                                                                            2203
# Accident (death or serious injury)                                               2181
# Illness, AMS, exhaustion, or frostbite                                           1868
# Success (subpeak, foresummit)                                                    1245
# Lack (or loss) of supplies, support or equipment                                 1066
# Did not attempt climb                                                            1004
# Unknown                                                                           582
# Lack of time                                                                      581
# Did not reach base camp                                                           306
# Success (claimed)                                                                 100
# Attempt rumored                                                                    17
# Name: termreason, dtype: int64
