# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# show full output
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

# %%
# dataset
data = pd.read_csv("E:\Maven_Analytics_Challenges\Everest_Challenge\HimalayanExpeditions\everest_data.csv")

data.shape
# Out:
# (89089, 60)

# %%
data.head()
# Out:
#        expid  membid  myear         fname      lname sex     yob    citizen  \
# 0  AMAD01101       2   2001         Rohan    Buckley   M  1972.0  Australia
# 1  AMAD01101       1   2001  Marc Cameron   Fairhead   M  1968.0  Australia
# 2  AMAD01101       3   2001          Mark  Schroeder   M  1960.0  Australia
# 3  AMAD01101       4   2001         Colin      Smith   M  1966.0  Australia
# 4  AMAD01101       5   2001         Naomi      Smith   F  1970.0  Australia
#
#    leader  hired  sherpa  msuccess  mclaimed  mdisputed  msolo  mtraverse  \
# 0   False  False   False     False     False      False  False      False
# 1    True  False   False     False     False      False  False      False
# 2   False  False   False     False     False      False  False      False
# 3   False  False   False     False     False      False  False      False
# 4   False  False   False     False     False      False  False      False
#
#     mski  mparapente  mspeed  mo2used  mo2climb  mo2sleep  death  year  \
# 0  False       False   False    False     False     False  False  2001
# 1  False       False   False    False     False     False  False  2001
# 2  False       False   False    False     False     False  False  2001
# 3  False       False   False    False     False     False  False  2001
# 4  False       False   False    False     False     False  False  2001
#
#    season    route1     nation        leaders  \
# 0  Spring  SW Ridge  Australia  Marc Fairhead
# 1  Spring  SW Ridge  Australia  Marc Fairhead
# 2  Spring  SW Ridge  Australia  Marc Fairhead
# 3  Spring  SW Ridge  Australia  Marc Fairhead
# 4  Spring  SW Ridge  Australia  Marc Fairhead
#
#                                  sponsor  success1  claimed  disputed  \
# 0  Australian Ama Dablam Expedition 2001     False    False     False
# 1  Australian Ama Dablam Expedition 2001     False    False     False
# 2  Australian Ama Dablam Expedition 2001     False    False     False
# 3  Australian Ama Dablam Expedition 2001     False    False     False
# 4  Australian Ama Dablam Expedition 2001     False    False     False
#
#     smtdate smtdays totdays  \
# 0  4/1/2001     7.0    26.0
# 1  4/1/2001     7.0    26.0
# 2  4/1/2001     7.0    26.0
# 3  4/1/2001     7.0    26.0
# 4  4/1/2001     7.0    26.0
#
#                                           termreason      accidents  o2used  \
# 0  Bad conditions (deep snow, avalanching, fallin...  not available   False
# 1  Bad conditions (deep snow, avalanching, fallin...  not available   False
# 2  Bad conditions (deep snow, avalanching, fallin...  not available   False
# 3  Bad conditions (deep snow, avalanching, fallin...  not available   False
# 4  Bad conditions (deep snow, avalanching, fallin...  not available   False
#
#      ski  parapente  traverse  tothired  smthired  totmembers  smtmembers  \
# 0  False      False     False         0         0           5           0
# 1  False      False     False         0         0           5           0
# 2  False      False     False         0         0           5           0
# 3  False      False     False         0         0           5           0
# 4  False      False     False         0         0           5           0
#
#    mdeaths  hdeaths  comrte  stdrte peakid      pkname       pkname2  heightm  \
# 0        0        0    True   False   AMAD  Ama Dablam  Amai Dablang     6814
# 1        0        0    True   False   AMAD  Ama Dablam  Amai Dablang     6814
# 2        0        0    True   False   AMAD  Ama Dablam  Amai Dablang     6814
# 3        0        0    True   False   AMAD  Ama Dablam  Amai Dablang     6814
# 4        0        0    True   False   AMAD  Ama Dablam  Amai Dablang     6814
#
#        location   himal                   region  open   pyear  \
# 0  Khumbu Himal  Khumbu  Khumbu-Rolwaling-Makalu  True  1961.0
# 1  Khumbu Himal  Khumbu  Khumbu-Rolwaling-Makalu  True  1961.0
# 2  Khumbu Himal  Khumbu  Khumbu-Rolwaling-Makalu  True  1961.0
# 3  Khumbu Himal  Khumbu  Khumbu-Rolwaling-Makalu  True  1961.0
# 4  Khumbu Himal  Khumbu  Khumbu-Rolwaling-Makalu  True  1961.0
#
#                pcountry                                         psummiters
# 0  New Zealand, USA, UK  Mike Gill, Wally Romanes, Barry Bishop, Michae...
# 1  New Zealand, USA, UK  Mike Gill, Wally Romanes, Barry Bishop, Michae...
# 2  New Zealand, USA, UK  Mike Gill, Wally Romanes, Barry Bishop, Michae...
# 3  New Zealand, USA, UK  Mike Gill, Wally Romanes, Barry Bishop, Michae...
# 4  New Zealand, USA, UK  Mike Gill, Wally Romanes, Barry Bishop, Michae...

# %%
# Now we will foucus on Mount Everest related data
# everest = data[data['pkname'].str.contains('everest', case=False, na=False)]
# everest.shape

# %%
# alternate way to filter
everest = data[data['peakid']=="EVER"].reset_index(drop=True)
everest.shape
# Out:
# (25356, 60)

# %%
everest.head()
# Out:
#        expid  membid  myear         fname        lname sex     yob    citizen  \
# 0  EVER01151       3   2001         Scott       Ferris   M  1972.0  Australia
# 1  EVER01151       2   2001          Paul        Karis   M  1969.0  Australia
# 2  EVER01151       1   2001      Theodore      Kossart   M  1968.0  Australia
# 3  EVER01151       4   2001       Patrick  Van Prooyen   M  1977.0  Australia
# 4  EVER01101       1   2001  Brant Edward       Didden   M  1970.0        USA
#
#    leader  hired  sherpa  msuccess  mclaimed  mdisputed  msolo  mtraverse  \
# 0   False  False   False     False     False      False  False      False
# 1   False  False   False     False     False      False  False      False
# 2    True  False   False     False     False      False  False      False
# 3   False  False   False     False     False      False  False      False
# 4    True  False   False     False     False      False  False      False
#
#     mski  mparapente  mspeed  mo2used  mo2climb  mo2sleep  death  year  \
# 0  False       False   False    False     False     False  False  2001
# 1  False       False   False    False     False     False  False  2001
# 2  False       False   False    False     False     False  False  2001
# 3  False       False   False    False     False     False  False  2001
# 4  False       False   False     True      True     False  False  2001
#
#    season          route1     nation           leaders  \
# 0  Spring  N Col-NE Ridge  Australia  Theodore Kossart
# 1  Spring  N Col-NE Ridge  Australia  Theodore Kossart
# 2  Spring  N Col-NE Ridge  Australia  Theodore Kossart
# 3  Spring  N Col-NE Ridge  Australia  Theodore Kossart
# 4  Spring  S Col-SE Ridge        USA      Brant Didden
#
#                                   sponsor  success1  claimed  disputed  \
# 0  2001 Australian North Ridge Expedition     False    False     False
# 1  2001 Australian North Ridge Expedition     False    False     False
# 2  2001 Australian North Ridge Expedition     False    False     False
# 3  2001 Australian North Ridge Expedition     False    False     False
# 4                           not available      True    False     False
#
#      smtdate smtdays totdays                              termreason  \
# 0  5/21/2001    51.0    57.0  Illness, AMS, exhaustion, or frostbite
# 1  5/21/2001    51.0    57.0  Illness, AMS, exhaustion, or frostbite
# 2  5/21/2001    51.0    57.0  Illness, AMS, exhaustion, or frostbite
# 3  5/21/2001    51.0    57.0  Illness, AMS, exhaustion, or frostbite
# 4  5/23/2001    48.0    51.0                     Success (main peak)
#
#                                            accidents  o2used    ski  \
# 0                                      not available   False  False
# 1                                      not available   False  False
# 2                                      not available   False  False
# 3                                      not available   False  False
# 4  O'Bryan trouble breathing (asthema) while desc...    True  False
#
#    parapente  traverse  tothired  smthired  totmembers  smtmembers  mdeaths  \
# 0      False     False         1         0           4           0        0
# 1      False     False         1         0           4           0        0
# 2      False     False         1         0           4           0        0
# 3      False     False         1         0           4           0        0
# 4      False     False         4         2           3           2        0
#
#    hdeaths  comrte  stdrte peakid   pkname  \
# 0        0    True    True   EVER  Everest
# 1        0    True    True   EVER  Everest
# 2        0    True    True   EVER  Everest
# 3        0    True    True   EVER  Everest
# 4        1    True    True   EVER  Everest
#
#                                pkname2  heightm      location   himal  \
# 0  Sagarmatha, Chomolungma, Qomolungma     8849  Khumbu Himal  Khumbu
# 1  Sagarmatha, Chomolungma, Qomolungma     8849  Khumbu Himal  Khumbu
# 2  Sagarmatha, Chomolungma, Qomolungma     8849  Khumbu Himal  Khumbu
# 3  Sagarmatha, Chomolungma, Qomolungma     8849  Khumbu Himal  Khumbu
# 4  Sagarmatha, Chomolungma, Qomolungma     8849  Khumbu Himal  Khumbu
#
#                     region  open   pyear            pcountry  \
# 0  Khumbu-Rolwaling-Makalu  True  1953.0  New Zealand, India
# 1  Khumbu-Rolwaling-Makalu  True  1953.0  New Zealand, India
# 2  Khumbu-Rolwaling-Makalu  True  1953.0  New Zealand, India
# 3  Khumbu-Rolwaling-Makalu  True  1953.0  New Zealand, India
# 4  Khumbu-Rolwaling-Makalu  True  1953.0  New Zealand, India
#
#                               psummiters
# 0  Edmund Hillary, Tenzing Norgay Sherpa
# 1  Edmund Hillary, Tenzing Norgay Sherpa
# 2  Edmund Hillary, Tenzing Norgay Sherpa
# 3  Edmund Hillary, Tenzing Norgay Sherpa
# 4  Edmund Hillary, Tenzing Norgay Sherpa

# %%
# save the filtered data to a new csv file
everest.to_csv("E:\Maven_Analytics_Challenges\Everest_Challenge\HimalayanExpeditions\MountEverestData.csv", index=False)

# %% [markdown]
# #### Trend of Summits & Deaths Over Time

# %%
# Group data by year
yearly_stats = everest.groupby('year').agg({
    'msuccess': 'sum',
    'death': 'sum'
}).reset_index()

# Group data by season
seasonal_stats = everest.groupby('season').agg({
    'msuccess': 'sum',
    'death': 'sum'
}).reset_index()

# %%
seasonal_stats
# Out:
#    season  msuccess  death
# 0  Autumn       287     70
# 1  Spring     12434    275
# 2  Summer         9      1
# 3  Winter        15      7

# %%
# show me the top 5 year with maximum summits
yearly_stats.sort_values(by=['msuccess'], ascending=False).head(100).reset_index(drop=True)
# Out:
#     year  msuccess  death
# 0   2019       872     11
# 1   2024       839     12
# 2   2018       810      5
# 3   2017       680      6
# 4   2013       679      8
# 5   2016       678      5
# 6   2023       673     18
# 7   2022       672     10
# 8   2007       611      7
# 9   2012       574     10
# 10  2011       541      4
# 11  2010       532      3
# 12  2006       483     11
# 13  2009       463      5
# 14  2021       461      7
# 15  2008       428      1
# 16  2004       335      7
# 17  2005       307      6
# 18  2003       264      4
# 19  2001       182      5
# 20  2002       158      3
# 21  2000       145      2
# 22  2014       133     17
# 23  1993       129      7
# 24  1998       119      4
# 25  1999       116      4
# 26  1996        98     15
# 27  1992        90      8
# 28  1997        85      9
# 29  1995        82      4
# 30  1990        72      4
# 31  1994        51      5
# 32  1988        50     10
# 33  1991        38      2
# 34  1985        30      7
# 35  2020        28      0
# 36  1978        25      2
# 37  1989        24      8
# 38  1983        23      3
# 39  1979        20      6
# 40  1982        18     11
# 41  1984        16      9
# 42  1975        15      3
# 43  1921        12      2
# 44  1922        11      7
# 45  1924        10      4
# 46  1973        10      1
# 47  1965         9      0
# 48  1980         8      4
# 49  1963         6      1
# 50  1981         5      0
# 51  1986         4      5
# 52  1976         4      1
# 53  1956         4      0
# 54  1970         4      8
# 55  1960         3      1
# 56  1953         2      0
# 57  1987         2      3
# 58  1977         2      0
# 59  1966         0      1
# 60  1964         0      1
# 61  1933         0      0
# 62  1934         0      1
# 63  1935         0      0
# 64  1936         0      0
# 65  1938         0      0
# 66  1947         0      0
# 67  1950         0      0
# 68  2015         0     14
# 69  1951         0      0
# 70  1952         0      1
# 71  1974         0      6
# 72  1972         0      1
# 73  1958         0      0
# 74  1971         0      1
# 75  1969         0      1
# 76  1967         0      0
# 77  1962         0      1

# %%
yearly_stats.sort_values(by=['death'], ascending=False).head(100).reset_index(drop=True)
# Out:
#     year  msuccess  death
# 0   2023       673     18
# 1   2014       133     17
# 2   1996        98     15
# 3   2015         0     14
# 4   2024       839     12
# 5   2006       483     11
# 6   1982        18     11
# 7   2019       872     11
# 8   2012       574     10
# 9   2022       672     10
# 10  1988        50     10
# 11  1997        85      9
# 12  1984        16      9
# 13  1992        90      8
# 14  1989        24      8
# 15  1970         4      8
# 16  2013       679      8
# 17  1922        11      7
# 18  2004       335      7
# 19  2007       611      7
# 20  1985        30      7
# 21  1993       129      7
# 22  2021       461      7
# 23  1974         0      6
# 24  2017       680      6
# 25  1979        20      6
# 26  2005       307      6
# 27  1994        51      5
# 28  2016       678      5
# 29  2001       182      5
# 30  2009       463      5
# 31  2018       810      5
# 32  1986         4      5
# 33  1980         8      4
# 34  1990        72      4
# 35  1924        10      4
# 36  2011       541      4
# 37  2003       264      4
# 38  1999       116      4
# 39  1998       119      4
# 40  1995        82      4
# 41  2010       532      3
# 42  2002       158      3
# 43  1983        23      3
# 44  1987         2      3
# 45  1975        15      3
# 46  1921        12      2
# 47  1978        25      2
# 48  1991        38      2
# 49  2000       145      2
# 50  1963         6      1
# 51  1934         0      1
# 52  1952         0      1
# 53  2008       428      1
# 54  1960         3      1
# 55  1962         0      1
# 56  1972         0      1
# 57  1976         4      1
# 58  1964         0      1
# 59  1971         0      1
# 60  1966         0      1
# 61  1969         0      1
# 62  1973        10      1
# 63  1947         0      0
# 64  1933         0      0
# 65  2020        28      0
# 66  1935         0      0
# 67  1936         0      0
# 68  1938         0      0
# 69  1951         0      0
# 70  1950         0      0
# 71  1981         5      0
# 72  1967         0      0
# 73  1953         2      0
# 74  1977         2      0
# 75  1956         4      0
# 76  1965         9      0
# 77  1958         0      0

# %%
# Plot 1: Summits and Deaths Over Time
plt.figure(figsize=(15, 7))
plt.subplot(2, 1, 1)
sns.lineplot(data=yearly_stats, x='year', y='msuccess', label='Summits', marker='o')
sns.lineplot(data=yearly_stats, x='year', y='death', label='Deaths', marker='o', color='red')
plt.title('Summits and Deaths on Everest Over Time')
plt.xlabel('Year')
plt.ylabel('Count')
plt.grid(True)
plt.legend()

# Plot 2: Seasonal Distribution of Summits and Deaths
plt.subplot(2, 1, 2)
season_melted = pd.melt(seasonal_stats, id_vars='season', value_vars=['msuccess', 'death'],
                        var_name='Outcome', value_name='Count')
sns.barplot(data=season_melted, x='season', y='Count', hue='Outcome', palette='Set2')
plt.title('Seasonal Distribution of Summits and Deaths')
plt.xlabel('Season')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# From the line chart showing summits and deaths per year:
#
# Summits have increased significantly since the 1990s, peaking in:
#
#  - 🏆 2019: 872 summits
#
#  - 2024: 839 summits
#
#  - 2018: 810 summits
#
# Death peaks are relatively low compared to summits:
#
#  - 2023 saw the highest death count in recent years (18 deaths).
#
#  - 2015 is notable for having 0 summits but 14 deaths, likely due to the Nepal earthquake disaster.
#
# Spring dominates Everest climbs, offering the most favorable weather windows and thus highest summit and death counts.
